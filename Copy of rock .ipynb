# %%
print("Enter Rock, Paper, or Scissors")
player1choice = input()
player2choice = input()



if player1choice == player2choice:
  print("Both players put " +player1choice+ ", it was a tie!")
elif player1choice ==  "Rock" and player2choice == "Paper":
  print("Paper beat Rock, so Player 2 wins!")
elif player1choice == "Paper" and player2choice == "Rock":
  print("Paper beat Rock, so Player 1 wins!")
elif player1choice == "Rock" and player2choice == "Scissors":
  print("Rock beat Scissors, so Player 1 wins! ")
elif player1choice == "Scissors" and player2choice == "Rock":
  print("Rock beat Scissors, so Player 2 wins!")
elif player1choice == "Scissors" and player2choice == "Paper":
  print("Scissors beat Paper, so Player 1 wins!")
elif player1choice == "Paper" and player2choice == "Scissors":
  print("Scissors beat Paper, so Player 2 wins!")
else:
  print("make sure your entry has the correct capitalization and spelling")
# Out:
# Enter Rock, Paper, or Scissors

# %%
import random
computer_score = 0
player_score = 0
possible_values = ["Rock", "Paper", "Scissors"]
keep_playing = "Yes"
while keep_playing == "Yes":
  print("Enter Rock, Paper, or Scissors")
  playerchoice = input()
  computerchoice = random.choice(possible_values)
  if playerchoice == computerchoice:
    print("Both players put " +playerchoice+ " ,it was a tie!")
    player_score += 1
    computer_score += 1
  elif playerchoice ==  possible_values[0] and computerchoice == possible_values[1]:
    print("Paper beat Rock, so Computer wins!")
    computer_score += 1
  elif playerchoice == possible_values[1] and computerchoice == possible_values[0]:
    print("Paper beat Rock, so Player wins!")
    player_score += 1
  elif playerchoice == possible_values[0] and computerchoice == possible_values[2]:
    print("Rock beat Scissors, so Player wins! ")
    player_score += 1
  elif playerchoice == possible_values[2] and computerchoice == possible_values[0]:
   print("Rock beat Scissors, so Computer wins!")
   computer_score += 1
  elif playerchoice == possible_values[2] and computerchoice == possible_values[1]:
    print("Scissors beat Paper, so Player wins!")
    player_score += 1
  elif playerchoice == possible_values[1] and computerchoice == possible_values [2]:
    print("Scissors beat Paper, so Computer wins!")
    computer_score += 1
  print("player_score = ", player_score)
  print("computer_score =", computer_score)
  print("Do you want to keep playing? Yes or No?")
  keep_playing = input()
# Out:
# Enter Rock, Paper, or Scissors
# Scissors
# Scissors beat Paper, so Player wins!
# player_score =  1
# computer_score = 0
# Do you want to keep playing? Yes or No?
# Yes
# Enter Rock, Paper, or Scissors
# Rock
# Both players put Rock ,it was a tie!
# player_score =  2
# computer_score = 1
# Do you want to keep playing? Yes or No?
# Yes
# Enter Rock, Paper, or Scissors
# Scissors
# Both players put Scissors ,it was a tie!
# player_score =  3
# computer_score = 2
# Do you want to keep playing? Yes or No?
# Yes
# Enter Rock, Paper, or Scissors
# Paper
# Scissors beat Paper, so Computer wins!
# player_score =  3
# computer_score = 3
# Do you want to keep playing? Yes or No?
# Yes
# Enter Rock, Paper, or Scissors
# Scissors
# Scissors beat Paper, so Player wins!
# player_score =  4
# computer_score = 3
# Do you want to keep playing? Yes or No?
# Yes
# Enter Rock, Paper, or Scissors
# Paper
# Paper beat Rock, so Player wins!
# player_score =  5
# computer_score = 3
# ...

# %%
count = 0
while count<5:
  print(count)
  count = count+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# efficient code
import random
computer_score = 0
player_score = 0
possible_values = ["Rock", "Paper", "Scissors"]
keep_playing = "Yes"
while keep_playing == "Yes":
  print("Enter Rock, Paper, or Scissors")
  playerchoice = input()
  computerchoice = random.choice(possible_values)
  if playerchoice == computerchoice:
    print("Both players put " +playerchoice+ " ,it was a tie!")
    player_score += 1
    computer_score += 1
  elif  computerchoice == possible_values[1]:
    if playerchoice == possible_values[0]:
      print("Paper beat Rock, so Computer wins!")
      computer_score += 1
    else:
      print("Scissors beat Paper, so Player wins!")
      player_score += 1
  elif computerchoice == possible_values[0]:
    if playerchoice == possible_values[1]:
      print("Paper beat Rock, so Player wins!")
      player_score += 1
    else:
      print("Rock beat Scissors, so Computer wins! ")
      computer_score += 1
  elif computerchoice == possible_values[2]:
   if playerchoice == possible_values[0]:
     print("Rock beat Scissors, so Player wins!")
     player_score += 1
   else:
     print("Scissors beat Paper, so Computer wins!")
     computer_score += 1


  print("player_score = ", player_score)
  print("computer_score =", computer_score)
  print("Do you want to keep playing? Yes or No?")
  keep_playing = input()
# Out:
# Enter Rock, Paper, or Scissors
